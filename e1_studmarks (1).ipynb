# %%
# !pip install mysql-connector-python

# %%
import mysql.connector

# %%
#fetching data from mysql to jupyter
import pandas as pd
con=mysql.connector.connect(
    host="localhost",
    port=3306,
    user="root",
    password="Vipin@12345",
    database="testdb")
df=pd.read_sql_query("select * from studmarks",con)
df
df.head(10)
# first 10 row of dataset
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M  1988-04-05     55       45         56       87       21
# 1    Suresh      M  1987-05-04     75       96         78       64       90
# 2    Ramesh      M  1989-05-25     25       54         89       76       95
# 3   Jessica      F  1990-08-12     78       96         86       63       54
# 4  Jennifer      F  1989-09-02     58       96         78       46       96
# 5      Annu      F  1988-04-05     45       87         52       89       55
# 6     pooja      F  1987-05-04     55       64         61       58       75
# 7    Ritesh      M  1989-05-25     54       76         87       56       25
# 8     Farha      F  1990-08-12     55       63         89       75       78
# 9    Mukesh      M  1989-09-02     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# ...

# %%
# last five row from the last
df.tail()
# Out:
#      Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 5    Annu      F  1988-04-05     45       87         52       89       55
# 6   pooja      F  1987-05-04     55       64         61       58       75
# 7  Ritesh      M  1989-05-25     54       76         87       56       25
# 8   Farha      F  1990-08-12     55       63         89       75       78
# 9  Mukesh      M  1989-09-02     96       46         77       83       58
#
#    Economics  History  Civics
# 5         89       87      52
# 6         58       64      61
# 7         56       76      87
# 8         75       63      89
# 9         83       46      77

# %%
df.shape  #output --- rows=10 and columns=11
# Out:
# (10, 11)

# %%
df.columns #  output---all columns name
# Out:
# Index(['Name', 'Gender', 'DOB', 'Maths', 'Physics', 'Chemistry', 'English',
#        'Biology', 'Economics', 'History', 'Civics'],
#       dtype='object')

# %%
#lets check datatypes of columns
df.dtypes
#name,gender,dob are the object datatype while others are int datatype
# Out:
# Name         object
# Gender       object
# DOB          object
# Maths         int64
# Physics       int64
# Chemistry     int64
# English       int64
# Biology       int64
# Economics     int64
# History       int64
# Civics        int64
# dtype: object

# %%
#To show the detailed summary 
df.info()
#no null value present
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
# Name         10 non-null object
# Gender       10 non-null object
# DOB          10 non-null object
# Maths        10 non-null int64
# Physics      10 non-null int64
# Chemistry    10 non-null int64
# English      10 non-null int64
# Biology      10 non-null int64
# Economics    10 non-null int64
# History      10 non-null int64
# Civics       10 non-null int64
# dtypes: int64(8), object(3)
# memory usage: 1008.0+ bytes

# %%
#lets check null values
df.isnull().sum()
#no null value present
# Out:
# Name         0
# Gender       0
# DOB          0
# Maths        0
# Physics      0
# Chemistry    0
# English      0
# Biology      0
# Economics    0
# History      0
# Civics       0
# dtype: int64

# %%
df.describe()   #summary statistics
# Out:
#            Maths    Physics  Chemistry    English    Biology  Economics  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   59.600000  72.300000  75.300000  69.700000  64.700000  72.700000
# std    19.460501  20.661559  14.000397  14.453373  26.998148  14.629119
# min    25.000000  45.000000  52.000000  46.000000  21.000000  52.000000
# 25%    54.250000  56.250000  65.000000  59.250000  54.250000  58.750000
# 50%    55.000000  70.000000  78.000000  69.500000  66.500000  76.000000
# 75%    70.750000  93.750000  86.750000  81.250000  87.000000  86.000000
# max    96.000000  96.000000  89.000000  89.000000  96.000000  89.000000
#
#          History   Civics
# count  10.000000  10.0000
# mean   69.700000  60.5000
# std    14.453373  25.3432
# min    46.000000   2.0000
# 25%    59.250000  52.2500
# 50%    69.500000  63.0000
# 75%    81.250000  76.2500
# max    89.000000  89.0000

# %%
#data visualization----to check missing values
import seaborn as sns
sns.heatmap(df.isnull())   #there is no missing value inside data

# %%
# checking correlation with the help of table
df.corr()
# Out:
#               Maths   Physics  Chemistry   English   Biology  Economics  \
# Maths      1.000000  0.113354   0.076751 -0.064074 -0.146598   0.000312
# Physics    0.113354  1.000000   0.117192 -0.562608  0.279638   0.191851
# Chemistry  0.076751  0.117192   1.000000 -0.409680  0.318032   0.235390
# English   -0.064074 -0.562608  -0.409680  1.000000 -0.330844   0.237577
# Biology   -0.146598  0.279638   0.318032 -0.330844  1.000000   0.370531
# Economics  0.000312  0.191851   0.235390  0.237577  0.370531   1.000000
# History   -0.320846  0.334082  -0.482710 -0.038775 -0.456131  -0.164953
# Civics    -0.274629 -0.643266   0.210908  0.186705 -0.330060   0.043905
#
#             History    Civics
# Maths     -0.320846 -0.274629
# Physics    0.334082 -0.643266
# Chemistry -0.482710  0.210908
# English   -0.038775  0.186705
# Biology   -0.456131 -0.330060
# Economics -0.164953  0.043905
# History    1.000000 -0.048686
# Civics    -0.048686  1.000000

# %%
# checking correlation with the help of graph
sns.heatmap(df.corr())
#physics and english are highly -vely correlated

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))   # for sns size
sns.heatmap(df.corr(),cmap='Blues',annot=True)  #annot=true gives sns with value

# %%
#lets check the skewness of dataset
df.skew()
#no skewness present in dataset
# Out:
# Maths        0.246964
# Physics     -0.045336
# Chemistry   -0.746462
# English     -0.131222
# Biology     -0.496446
# Economics   -0.245555
# History     -0.131222
# Civics      -1.332448
# dtype: float64

# %%
df.drop('DOB',axis=1,inplace=True) 
df
# Out:
#        Name Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0      John      M     55       45         56       87       21         52
# 1    Suresh      M     75       96         78       64       90         61
# 2    Ramesh      M     25       54         89       76       95         87
# 3   Jessica      F     78       96         86       63       54         89
# 4  Jennifer      F     58       96         78       46       96         77
# 5      Annu      F     45       87         52       89       55         89
# 6     pooja      F     55       64         61       58       75         58
# 7    Ritesh      M     54       76         87       56       25         56
# 8     Farha      F     55       63         89       75       78         75
# 9    Mukesh      M     96       46         77       83       58         83
#
#    History  Civics
# 0       89      65
# 1       58       2
# 2       56      74
# 3       75      45
# 4       83      53
# 5       87      52
# ...

# %%
df1=df.copy()
df1
# Out:
#        Name Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0      John      M     55       45         56       87       21         52
# 1    Suresh      M     75       96         78       64       90         61
# 2    Ramesh      M     25       54         89       76       95         87
# 3   Jessica      F     78       96         86       63       54         89
# 4  Jennifer      F     58       96         78       46       96         77
# 5      Annu      F     45       87         52       89       55         89
# 6     pooja      F     55       64         61       58       75         58
# 7    Ritesh      M     54       76         87       56       25         56
# 8     Farha      F     55       63         89       75       78         75
# 9    Mukesh      M     96       46         77       83       58         83
#
#    History  Civics
# 0       89      65
# 1       58       2
# 2       56      74
# 3       75      45
# 4       83      53
# 5       87      52
# ...

# %%
df.drop('Name',axis=1,inplace=True)

# %%
df
# Out:
#   Gender  Maths  Physics  Chemistry  English  Biology  Economics  History  \
# 0      M     55       45         56       87       21         52       89
# 1      M     75       96         78       64       90         61       58
# 2      M     25       54         89       76       95         87       56
# 3      F     78       96         86       63       54         89       75
# 4      F     58       96         78       46       96         77       83
# 5      F     45       87         52       89       55         89       87
# 6      F     55       64         61       58       75         58       64
# 7      M     54       76         87       56       25         56       76
# 8      F     55       63         89       75       78         75       63
# 9      M     96       46         77       83       58         83       46
#
#    Civics
# 0      65
# 1       2
# 2      74
# 3      45
# 4      53
# 5      52
# 6      61
# 7      87
# 8      89
# 9      77

# %%
# using categorical data into numeric format using label encoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Gender']=le.fit_transform(df['Gender'])
df
# Out:
#    Gender  Maths  Physics  Chemistry  English  Biology  Economics  History  \
# 0       1     55       45         56       87       21         52       89
# 1       1     75       96         78       64       90         61       58
# 2       1     25       54         89       76       95         87       56
# 3       0     78       96         86       63       54         89       75
# 4       0     58       96         78       46       96         77       83
# 5       0     45       87         52       89       55         89       87
# 6       0     55       64         61       58       75         58       64
# 7       1     54       76         87       56       25         56       76
# 8       0     55       63         89       75       78         75       63
# 9       1     96       46         77       83       58         83       46
#
#    Civics
# 0      65
# 1       2
# 2      74
# 3      45
# 4      53
# 5      52
# 6      61
# 7      87
# 8      89
# 9      77

# %%
# checking outlier
from scipy.stats import zscore
z_score=abs(zscore(df))
print(df.shape)
df1=df.loc[(z_score<3).all(axis=1)]
print(df1.shape)
#no outlier present in dataset
# Out:
# (10, 9)
# (10, 9)

# %% [markdown]
# # univarient and multivarient analysis

# %%
df['Gender'].plot.box() #this contain outlier values

# %%
df1['Maths'].plot.box() # shows range of maths marks

# %%
df1['Physics'].plot.box()   # shows range of Physics marks

# %%
df1['Chemistry'].plot.box()      #shows range of Chemistry marks

# %%
df1['English'].plot.box()       #shows range of English marks

# %%
df1['Biology'].plot.box()

# %%
df1['Economics'].plot.box()

# %%
df1['History'].plot.box()

# %%
df1['Civics'].plot.box()

# %%
#this code is for boxplot together
collist=df.columns.values
ncol=12
nrows=10
plt.figure(figsize=(ncol,5*ncol))
for i in range(1,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %%
sns.distplot(df['Maths'])  # showing range of marks of different subject

# %%
sns.distplot(df['Physics'])

# %%
sns.distplot(df['Chemistry'])    #showing range of marks of different subject

# %%
sns.distplot(df['English'])

# %%
sns.distplot(df['Economics'])

# %%
sns.distplot(df['Biology'])

# %%
sns.distplot(df['Civics'])      #showing range of marks of different subject

# %%
sns.distplot(df['Gender'])   #showing range of marks of different subject

# %%
sns.barplot(x='Gender',y='Maths',data=df)
plt.show()
#gender 1 got the highest marks in maths

# %%
sns.barplot(x='Gender',y='Physics',data=df)   #gender 0 got the highest marks in physics
plt.show()

# %%
sns.barplot(x='Chemistry',y='Gender',data=df)  #below graph showing chemistry marks on the basis of gender
plt.show()

# %%
sns.barplot(x='Gender',y='English',data=df)
plt.show()

# %%
sns.barplot(x='Gender',y='Biology',data=df)
plt.show()

# %%
sns.barplot(x='Gender',y='Economics',data=df)
plt.show()

# %%
sns.barplot(x='Gender',y='Biology',data=df)
plt.show()

# %%
sns.barplot(x='Gender',y='History',data=df)
plt.show()

# %%
sns.barplot(x='Gender',y='Civics',data=df)
plt.show()

# %%
df1.Gender.value_counts()
#gender1=5 student
#gender0=5 student
# Out:
# 1    5
# 0    5
# Name: Gender, dtype: int64

# %%
sns.countplot(x='Gender', data=df1)
#gender1=5 student
#gender0=5 student

# %%
sns.countplot(x='Maths', data=df1)
#no of count on the basis of maths marks
#like one student got 25  marks
# and 3 student got 55 marks

# %%
sns.countplot(x='Physics', data=df1)
#3 student got 96 marks in physics

# %%
sns.countplot(x='Chemistry', data=df1)
# 2-2 student got 78 and 89 marks

# %%
sns.countplot(x='Economics', data=df1)
# 2 student got 89 marks

# %%
sns.countplot(x='Biology', data=df1)

# %%
sns.countplot(x='History', data=df1)
# each student got different marks

# %%
sns.countplot(x='Civics', data=df1)
# each student got different marks

# %%
sns.countplot(x='English', data=df1)
# each student got different marks

# %%
#violinplot 
fig = plt.figure(figsize = (10,6))
sns.violinplot(x = 'Gender', y = 'Maths', data = df1)
# distribution of marks on basis of gender

# %%
#violinplot 
fig = plt.figure(figsize = (10,6))
sns.violinplot(x = 'Gender', y = 'Physics', data = df1)
#distribution of marks on basis of gender

# %%
#violinplot 
fig = plt.figure(figsize = (10,6))
sns.violinplot(x = 'Gender', y = 'Chemistry', data = df1)
# distribution of marks on basis of gender

# %%
#violinplot 
fig = plt.figure(figsize = (10,6))
sns.violinplot(x = 'Gender', y = 'Biology', data = df1)
# distribution of marks on basis of gender

# %%
#violinplot 
fig = plt.figure(figsize = (10,6))
sns.violinplot(x = 'Gender', y = 'Economics', data = df1)
# distribution of marks on basis of gender

# %%
#violinplot 
fig = plt.figure(figsize = (10,6))
sns.violinplot(x = 'Gender', y = 'History', data = df1)
# distribution of marks on basis of gender

# %%
#violinplot 
fig = plt.figure(figsize = (10,6))
sns.violinplot(x = 'Gender', y = 'Civics', data = df1)
# distribution of marks on basis of gender

# %%
#violinplot 
fig = plt.figure(figsize = (10,6))
sns.violinplot(x = 'Gender', y = 'English', data = df1)
# distribution of marks on basis of gender

# %%
ax=sns.swarmplot(x='Maths',y='Gender',data=df)
plt.title('Graph')
plt.show()
# distribution of marks on basis of gender

# %%
sns.pairplot(df1)

# %%
df1['Physics'].sum()
# Out:
# 723

# %%
df1['Maths'].sum()
# Out:
# 596

# %%
df1['Chemistry'].sum()
# Out:
# 753

# %%
df1['English'].sum()
# Out:
# 697

# %%
df1['Biology'].sum()
# Out:
# 647

# %%
df1['Civics'].sum()
# Out:
# 605

# %%
df1['Economics'].sum()
# Out:
# 727

# %%
df1['History'].sum()
# Out:
# 697

# %% [raw]
# In chemistry students perform better
# In maths students perform not good as expected
